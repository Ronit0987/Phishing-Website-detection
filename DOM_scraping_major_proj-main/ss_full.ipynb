# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import WebDriverException
import os
import pandas as pd

# %%
df=pd.read_csv("F://edge_downloads//verified_online.csv")
df=df.head(1500)
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 2      8467079                           http://aweqdh.csszx.xyz/
# 3      8467078                           http://sfghcf.csszx.xyz/
# 4      8467077              https://ads-manage.miracle-chain.com/
# ...        ...                                                ...
# 1495   8464132                               https://mufsjjq.icu/
# 1496   8464131                               https://mufsjic.icu/
# 1497   8464126  https://www.fattura.ltd/mZiyOv-HUi1X-DUObU-br1...
# 1498   8464125                  https://www.fattura.ltd/index.php
# 1499   8464124  https://www.fatturazione.ltd/AWryUF-zFX6Y-QOlB...
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df1=pd.read_csv("C://Users//admin//Downloads//merged_df.csv")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException, WebDriverException
import os
import pandas as pd

# Assuming 'df' is a pandas DataFrame with 'type' and 'url' columns
# Let's create a dummy 'df' for demonstration purposes


# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration

# Initialize Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)
driver.set_page_load_timeout(10)  # Timeout set to 10 seconds

# Create a directory to save DOM tree files
directory_name = 'F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish'
os.makedirs(directory_name, exist_ok=True)

# Add a 'size' column to the dataframe to store the size of the DOM tree
df['size'] = None

for index, row in df.iterrows():
    url = row['url'].rstrip('/')
    
    try:
        # Open the URL with a timeout
        driver.get(url)

        # Get the DOM tree
        dom_tree = driver.page_source

        # Save the DOM tree to a file
        filename = os.path.join(directory_name, f"{index+1}_dom_tree.html")  # Using index+1 for filename numbering
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(dom_tree)

        # Update the 'size' column with the size of the DOM tree
        df.at[index, 'size'] = len(dom_tree)
        df.at[index, 'serial_no'] = index + 1
        print(f"DOM tree saved for {url} as {filename}")

    except (TimeoutException, WebDriverException) as e:
        print(f"Error occurred while loading {url}: {str(e)}. Proceeding to the next URL.")

# Quit the WebDriver
driver.quit()
# Print the updated dataframe
print(df)
# Out:
# DOM tree saved for https://beneficioauxbrasil.com as F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish\1_dom_tree.html
# DOM tree saved for https://secure-ads-manage.miracle-chain.com/bussines-service as F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish\2_dom_tree.html
# Error occurred while loading http://aweqdh.csszx.xyz: Message: unknown error: net::ERR_CONNECTION_REFUSED
#   (Session info: chrome-headless-shell=123.0.6312.122)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7524A7032+63090]
# 	(No symbol) [0x00007FF752412C82]
# 	(No symbol) [0x00007FF7522AEC65]
# 	(No symbol) [0x00007FF7522AAC1A]
# 	(No symbol) [0x00007FF75229D514]
# 	(No symbol) [0x00007FF75229E8F8]
# 	(No symbol) [0x00007FF75229D7FF]
# 	(No symbol) [0x00007FF75229D104]
# 	(No symbol) [0x00007FF75229D021]
# 	(No symbol) [0x00007FF75229B0A8]
# 	(No symbol) [0x00007FF75229B8BC]
# 	(No symbol) [0x00007FF7522B14AD]
# 	(No symbol) [0x00007FF752333D67]
# 	(No symbol) [0x00007FF752316FDA]
# ...

# %%
df.head(50)
# Out:
#     phish_id                                                url  \
# 0    8467088                     https://beneficioauxbrasil.com
# 1    8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 2    8467079                           http://aweqdh.csszx.xyz/
# 3    8467078                           http://sfghcf.csszx.xyz/
# 4    8467077              https://ads-manage.miracle-chain.com/
# 5    8467076                           http://bghyii.csszx.xyz/
# 6    8467075                           http://dfahru.cdxxa.xyz/
# 7    8467073                           http://vcnfte.cdxxa.xyz/
# 8    8467072                           http://aestrf.cdxxa.xyz/
# 9    8467071                           http://xfgngf.cdxxa.xyz/
# 10   8467070                           http://dfhtoo.vuyre.xyz/
# 11   8467069                           http://sdfger.vuyre.xyz/
# 12   8467068                           http://hjbngt.vuyre.xyz/
# 13   8467067                           http://xvbnyg.cxwrt.xyz/
# ...

# %%
df.to_csv('F://React_projs2//DOM_scraping_major_proj//df_with_serial.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# url            0
# type           0
# size          40
# dtype: int64

# %%
df.isnull()

# %%
# Drop rows where a specific column contains the string 'None'
df.drop(df[df['size'] == 'None'].index)
df
# Out:
#     Unnamed: 0                                                url      type  \
# 0            0                     https://beneficioauxbrasil.com  phishing
# 1            1  https://secure-ads-manage.miracle-chain.com/bu...  phishing
# 2            2                           http://aweqdh.csszx.xyz/  phishing
# 3            3                           http://sfghcf.csszx.xyz/  phishing
# 4            4              https://ads-manage.miracle-chain.com/  phishing
# ..         ...                                                ...       ...
# 95          95           http://allegrolokalnie.id-oferta85727.pl  phishing
# 96          96           http://allegrolokalnie.id-oferta11900.pl  phishing
# 97          97           https://allegrolokalnie.id-oferta5755.pl  phishing
# 98          98           http://allegrolokalnie.id-oferta77800.pl  phishing
# 99          99   https://bt-customer-verification.weeblysite.com/  phishing
#
#      size
# 0       0
# 1     810
# 2      39
# ...

# %%
df.dropna(subset=['size'],inplace=True)
df
# Out:
#     Unnamed: 0                                                url      type  \
# 0            0                     https://beneficioauxbrasil.com  phishing
# 1            1  https://secure-ads-manage.miracle-chain.com/bu...  phishing
# 2            2                           http://aweqdh.csszx.xyz/  phishing
# 3            3                           http://sfghcf.csszx.xyz/  phishing
# 5            5                           http://bghyii.csszx.xyz/  phishing
# 6            6                           http://dfahru.cdxxa.xyz/  phishing
# 7            7                           http://vcnfte.cdxxa.xyz/  phishing
# 8            8                           http://aestrf.cdxxa.xyz/  phishing
# 9            9                           http://xfgngf.cdxxa.xyz/  phishing
# 10          10                           http://dfhtoo.vuyre.xyz/  phishing
# 11          11                           http://sdfger.vuyre.xyz/  phishing
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException, WebDriverException
import os
import pandas as pd

# Assuming 'df' is a pandas DataFrame with 'type' and 'url' columns
# Let's create a dummy 'df' for demonstration purposes


# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration

# Initialize Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)
driver.set_page_load_timeout(10)  # Timeout set to 10 seconds

# Create a directory to save DOM tree files
if not os.path.exists('dom_trees'):
    os.makedirs('dom_trees')

# Add a 'size' column to the dataframe to store the size of the DOM tree
new_df['size'] = None

for index, row in new_df.iterrows():
    url_type = row['type']
    url = row['url'].rstrip('/')

    try:
        # Open the URL with a timeout
        driver.get(url)

        # Get the DOM tree
        dom_tree = driver.page_source

        # Save the DOM tree to a file
        filename = f"dom_trees/{index+1}_dom_tree.html"  # Using index+1 for filename numbering
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(dom_tree)

        # Update the 'size' column with the size of the DOM tree
        new_df.at[index, 'size'] = len(dom_tree)

        print(f"DOM tree saved for {url} as {filename}")

    except (TimeoutException, WebDriverException) as e:
        print(f"Error occurred while loading {url}: {str(e)}. Proceeding to the next URL.")

# Quit the WebDriver
driver.quit()

# Print the updated dataframe
print(new_df)
# Out:
# DOM tree saved for https://www.facebook.com/people/Reggie-Walton/1070104441 as dom_trees/48755_dom_tree.html
# Error occurred while loading https://www.freepages.genealogy.rootsweb.ancestry.com/~dwdrury/abell/index3.htm: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome-headless-shell=123.0.6312.58)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF78FBD7062+63090]
# 	(No symbol) [0x00007FF78FB42CB2]
# 	(No symbol) [0x00007FF78F9DEC65]
# 	(No symbol) [0x00007FF78F9DAC1A]
# 	(No symbol) [0x00007FF78F9CD514]
# 	(No symbol) [0x00007FF78F9CE8F8]
# 	(No symbol) [0x00007FF78F9CD7FF]
# 	(No symbol) [0x00007FF78F9CD104]
# 	(No symbol) [0x00007FF78F9CD021]
# 	(No symbol) [0x00007FF78F9CB0A8]
# 	(No symbol) [0x00007FF78F9CB8BC]
# 	(No symbol) [0x00007FF78F9E14AD]
# 	(No symbol) [0x00007FF78FA63D67]
# 	(No symbol) [0x00007FF78FA46FDA]
# 	(No symbol) [0x00007FF78FA63412]
# 	(No symbol) [0x00007FF78FA46D83]
# 	(No symbol) [0x00007FF78FA183A8]
# ...

# %%
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 2      8467079                           http://aweqdh.csszx.xyz/
# 3      8467078                           http://sfghcf.csszx.xyz/
# 4      8467077              https://ads-manage.miracle-chain.com/
# ...        ...                                                ...
# 1495   8464132                               https://mufsjjq.icu/
# 1496   8464131                               https://mufsjic.icu/
# 1497   8464126  https://www.fattura.ltd/mZiyOv-HUi1X-DUObU-br1...
# 1498   8464125                  https://www.fattura.ltd/index.php
# 1499   8464124  https://www.fatturazione.ltd/AWryUF-zFX6Y-QOlB...
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df.isnull().sum()
# Out:
# phish_id               0
# url                    0
# phish_detail_url       0
# submission_time        0
# verified               0
# verification_time      0
# online                 0
# target                 0
# size                 639
# dtype: int64

# %%
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 2      8467079                           http://aweqdh.csszx.xyz/
# 3      8467078                           http://sfghcf.csszx.xyz/
# 4      8467077              https://ads-manage.miracle-chain.com/
# ...        ...                                                ...
# 1495   8464132                               https://mufsjjq.icu/
# 1496   8464131                               https://mufsjic.icu/
# 1497   8464126  https://www.fattura.ltd/mZiyOv-HUi1X-DUObU-br1...
# 1498   8464125                  https://www.fattura.ltd/index.php
# 1499   8464124  https://www.fatturazione.ltd/AWryUF-zFX6Y-QOlB...
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df=df.dropna(subset=['size'])
df.shape
# Out:
# (830, 10)

# %%
df.isnull().sum()
# Out:
# phish_id             0
# url                  0
# phish_detail_url     0
# submission_time      0
# verified             0
# verification_time    0
# online               0
# target               0
# size                 0
# serial_no            0
# dtype: int64

# %%
df2_serial=df.copy()

# %%
df=df2_serial

# %%
df1=pd.read_csv("F://edge_downloads//verified_online.csv")

# %%
df.loc[df['serial_no']==179]
# Out:
#      phish_id                                                url  \
# 178   8466742  https://www.floridavacationrentalsbyowners.com...
#
#                                       phish_detail_url  \
# 178  http://www.phishtank.com/phish_detail.php?phis...
#
#                submission_time verified          verification_time online  \
# 178  2024-02-26T02:52:12+00:00      yes  2024-02-26T03:03:27+00:00    yes
#
#     target   size  serial_no
# 178  Optus  47378        179

# %%
df = df[df['serial_no'] != 1407]
df['serial_no']=df['serial_no'].astype('Int64')

# %%
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Function to read HTML content from a file
def read_html_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# Function to compute TF-IDF scores of HTML tags from a file
def tf_idf_tags(file_path):
    html_content = read_html_file(file_path)

    # Check if HTML content is empty
    if not html_content.strip():
        return {}  # Return an empty dictionary if content is empty

    # Parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract tags from the DOM tree
    tags = [tag.name for tag in soup.find_all()]

    # Convert tags to string for TF-IDF computation
    tag_string = ' '.join(tags)

    # Compute TF-IDF scores
    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform([tag_string])

    # Get feature names (tags)
    feature_names = tfidf.get_feature_names_out()

    # Create a dictionary to store TF-IDF scores for each tag
    tag_tfidf_scores = {}
    for tag, score in zip(feature_names, tfidf_matrix.toarray()[0]):
        tag_tfidf_scores[tag] = score
    return tag_tfidf_scores

# Function to calculate similarity score between two documents based on their TF-IDF scores
def cal_similarity_score(idx):
    file_path1 = "F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish//" + str(idx) + "_dom_tree.html"
    tf_idf_tag = tf_idf_tags(file_path1)

    # Check if tf_idf_tag is empty
    if not tf_idf_tag:
        return 0  # Return 0 similarity score if tf_idf_tag is empty

    # Get tags from the reference document
    tags = set(res.keys()).union(set(tf_idf_tag.keys()))

    # Compute TF-IDF vectors for both documents
    vector_page1 = np.array([res.get(tag, 0) for tag in tags]).reshape(1, -1)
    vector_page2 = np.array([tf_idf_tag.get(tag, 0) for tag in tags]).reshape(1, -1)

    # Compute cosine similarity
    similarity_score = cosine_similarity(vector_page1, vector_page2)[0][0]
    return similarity_score

# File path of the reference HTML file

count=0
# Calculate TF-IDF scores for the reference HTML file
file_path="F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish//943_dom_tree.html"
res = tf_idf_tags(file_path)

# Print TF-IDF scores for each tag
for tag, score in sorted(res.items(), key=lambda x: x[1], reverse=True):
    print(f"{tag}: {score}")
df['similarity_score']=None
# Calculate and print similarity scores for other documents
for idx in df['serial_no']:
    similarity_score = cal_similarity_score(idx)
    df['similarity_score'].iloc[count]=similarity_score
    count=count+1
    print(f"Similarity score for document {idx}: {similarity_score}")
# Out:
# div: 0.7980868844676221
# script: 0.39904344223381105
# iframe: 0.23942606534028665
# meta: 0.23942606534028665
# link: 0.15961737689352443
# body: 0.07980868844676221
# form: 0.07980868844676221
# h1: 0.07980868844676221
# h4: 0.07980868844676221
# head: 0.07980868844676221
# html: 0.07980868844676221
# main: 0.07980868844676221
# style: 0.07980868844676221
# textarea: 0.07980868844676221
# title: 0.07980868844676221
# Similarity score for document 1: 0.42324948598732526
# Similarity score for document 2: 0.6911635163761372
# Similarity score for document 19: 0.10240239918736709
# Similarity score for document 20: 0.10240239918736709
# Similarity score for document 22: 0.8940094180475602
# Similarity score for document 23: 0.781986496946936
# Similarity score for document 26: 0.13823270327522746
# Similarity score for document 27: 0.8329451988945639
# Similarity score for document 31: 0.5800756124037196
# Similarity score for document 32: 0.15082424435169045
# ...

# %%
np.average(df['similarity_score'])
# Out:
# 0.6140171520768293

# %%
df.to_csv('F://React_projs2//DOM_scraping_major_proj//df_with_sim_943.csv')

# %% [markdown]
# ## Extracting Features of Website

# %%
df[['num_forms', 'has_login_form', 'num_scripts', 'has_external_scripts','num_hyperlinks', 'num_external_hyperlinks', 'num_js_events']]=None
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 18     8467054  https://pub-3ef4c4f0dccc42ab9f9604f18c4b3622.r...
# 19     8467053  https://googleweblight.com/i?u=https://pub-3ef...
# 21     8467042                         https://00-ird.weebly.com/
# ...        ...                                                ...
# 1393   8464267  https://docs.google.com/presentation/d/e/2PACX...
# 1394   8464266                          https://shorturl.at/gkl27
# 1398   8464261                       https://tinyurl.com/mvnzpks8
# 1399   8464260                       https://tinyurl.com/5bjcmv29
# 1403   8464255                       https://tinyurl.com/3zbuyeth
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
features
# Out:
# {'num_forms': 0,
#  'has_login_form': False,
#  'num_scripts': 0,
#  'has_external_scripts': False,
#  'num_hyperlinks': 2,
#  'num_external_hyperlinks': 1,
#  'num_js_events': 0}

# %%
from bs4 import BeautifulSoup
import requests
import re

# Function to extract features from HTML content
def extract_features(html_content):
    features = {}
    
    # Parse HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Extract URL features
    url = soup.find('meta', attrs={'property': 'og:url'})
    #features['url_length'] = len(url['content']) if url else 0
    
    # Extract form features
    forms = soup.find_all('form')
    features['num_forms'] = len(forms)
    features['has_login_form'] = any(['login' in form.get('action', '').lower() for form in forms])
    
    # Extract script features
    scripts = soup.find_all('script')
    features['num_scripts'] = len(scripts)
    features['has_external_scripts'] = any(['http' in script.get('src', '') for script in scripts])
    
    # Extract hyperlink features
    hyperlinks = soup.find_all('a', href=True)
    features['num_hyperlinks'] = len(hyperlinks)
    features['num_external_hyperlinks'] = sum(1 for link in hyperlinks if 'http' in link['href'])
    
    # Extract JavaScript event features
    js_events = soup.find_all(re.compile('^on'))
    features['num_js_events'] = len(js_events)
    
    return features

# Example URL for testing
count=0
for idx in df['serial_no']:
    file_path1 = "F://React_projs2//DOM_scraping_major_proj//dom_trees_new_phish//" + str(idx) + "_dom_tree.html"
    html_content = read_html_file(file_path1)
    features=extract_features(html_content)
    df['num_forms'].iloc[count]=features['num_forms']
    df['has_login_form'].iloc[count]=features['has_login_form']
    df['num_scripts'].iloc[count]=features['num_scripts']
    df['has_external_scripts'].iloc[count]=features['has_external_scripts']
    df['num_hyperlinks'].iloc[count]=features['num_hyperlinks']
    df['num_external_hyperlinks'].iloc[count]=features['num_external_hyperlinks']
    df['num_js_events'].iloc[count]=features['num_js_events']
    count=count+1
    #print(features)

# # Fetch HTML content from the URL
# response = requests.get(url)
# html_content = response.text

# # Extract features from HTML content
# features = extract_features(html_content)

# # Print extracted features
# print("Extracted Features:")
# for key, value in features.items():
#     print(f"{key}: {value}")
# Out:
# C:\Users\Aarya\AppData\Local\Temp\ipykernel_15388\2788146603.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_forms'].iloc[count]=features['num_forms']
# C:\Users\Aarya\AppData\Local\Temp\ipykernel_15388\2788146603.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['has_login_form'].iloc[count]=features['has_login_form']
# C:\Users\Aarya\AppData\Local\Temp\ipykernel_15388\2788146603.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 18     8467054  https://pub-3ef4c4f0dccc42ab9f9604f18c4b3622.r...
# 19     8467053  https://googleweblight.com/i?u=https://pub-3ef...
# 21     8467042                         https://00-ird.weebly.com/
# ...        ...                                                ...
# 1393   8464267  https://docs.google.com/presentation/d/e/2PACX...
# 1394   8464266                          https://shorturl.at/gkl27
# 1398   8464261                       https://tinyurl.com/mvnzpks8
# 1399   8464260                       https://tinyurl.com/5bjcmv29
# 1403   8464255                       https://tinyurl.com/3zbuyeth
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df_with_features=df.copy()

# %%
df=df_with_features

# %%
df['has_login_form']=df['has_login_form'].map({True:1,False:0})
df['has_login_form']
# Out:
# 0       0
# 1       0
# 18      0
# 19      0
# 21      0
#        ..
# 1393    0
# 1394    0
# 1398    0
# 1399    0
# 1403    0
# Name: has_login_form, Length: 817, dtype: int64

# %%
df['has_external_scripts']=df['has_external_scripts'].map({True:1,False:0})
df['has_external_scripts']
# Out:
# 0       1
# 1       0
# 18      0
# 19      0
# 21      1
#        ..
# 1393    0
# 1394    0
# 1398    0
# 1399    0
# 1403    0
# Name: has_external_scripts, Length: 817, dtype: int64

# %%
df['isPhishing']=1
df
# Out:
#       phish_id                                                url  \
# 0      8467088                     https://beneficioauxbrasil.com
# 1      8467085  https://secure-ads-manage.miracle-chain.com/bu...
# 18     8467054  https://pub-3ef4c4f0dccc42ab9f9604f18c4b3622.r...
# 19     8467053  https://googleweblight.com/i?u=https://pub-3ef...
# 21     8467042                         https://00-ird.weebly.com/
# ...        ...                                                ...
# 1393   8464267  https://docs.google.com/presentation/d/e/2PACX...
# 1394   8464266                          https://shorturl.at/gkl27
# 1398   8464261                       https://tinyurl.com/mvnzpks8
# 1399   8464260                       https://tinyurl.com/5bjcmv29
# 1403   8464255                       https://tinyurl.com/3zbuyeth
#
#                                        phish_detail_url  \
# 0     http://www.phishtank.com/phish_detail.php?phis...
# 1     http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df.to_csv('F://React_projs2//DOM_scraping_major_proj//df_phishing_with_features.csv')
